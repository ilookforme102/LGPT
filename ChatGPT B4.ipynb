# %%
#In this file, the whole process of scrapinng 1000 job posts url from LinkedIn
#and craping all the necessary data related to content of each job post

from selenium import webdriver 
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException,ElementClickInterceptedException
#from retry import retry
import pandas as pd
import os
from selenium.common.exceptions import TimeoutException
import csv
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import time
import undetected_chromedriver as uc
# Out:
# /Users/macbook/opt/anaconda3/lib/python3.9/site-packages/requests/__init__.py:102: RequestsDependencyWarning: urllib3 (1.26.9) or chardet (5.1.0)/charset_normalizer (2.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({})/charset_normalizer ({}) doesn't match a supported "

# %%
#Setup Username and password of your LinkedIn
username = 'shang.caokhac@gmail.com'
password ='BBz30002'

# %%
#Setup browser profile
uc.TARGET_VERSION = 115
options = uc.ChromeOptions() 
options.headless = True 
driver = uc.Chrome()
driver.get("https://chat.openai.com/") 
time.sleep(20)
# Out:
# /var/folders/m_/j0tcz1vn06q4ndgrzrp_yxpm0000gn/T/ipykernel_17513/3641939889.py:4: DeprecationWarning: headless property is deprecated, instead use add_argument('--headless') or add_argument('--headless=new')
#   options.headless = True

# %%
#driver.maximize_window()

# %%
## It will click on the first button on the screeen
login_button = driver.find_element(By.TAG_NAME,'button')
login_button.click()
time.sleep(10)

# %%
#pop-up will display and we need to fill in the email
username_field = driver.find_element(By.ID,'username')
username_field.send_keys(username)
time.sleep(3)

# %%
#click on continue button
continue_button = driver.find_element(By.TAG_NAME,'button')
continue_button.click()
time.sleep(10)

# fill in password
password_field = driver.find_element(By.ID,'password')
password_field.send_keys(password)
time.sleep(3)
# click on the "continue" button to login
btn =  driver.find_element(By.TAG_NAME,'button')
driver.execute_script ("arguments[0].click();",btn)
time.sleep(14)

# %%
#Next1, click any element has text =. "Next"
next1 =  driver.find_element(By.XPATH,'//*[text()="Next"]')
next1.click()
time.sleep(3)
#Next2 click any element has text =. "Next"
next2 =  driver.find_element(By.XPATH,'//*[text()="Next"]')
next2.click()
time.sleep(3)
#done click any element has text =. "Done"
done1 =  driver.find_element(By.XPATH,'//*[text()="Done"]')
done1.click()
time.sleep(3)

# %%
outline_brand_TDTC= [
"Tổng quan về cổng game TDTC( bao gồm lịch sử hình thành, giấy phép)",
"Ưu điểm của TDTC (bao gồm Giao diện đẹp mắt,Nạp rút dễ dàng và bảo mật,hỗ trợ đa nền tảng,dịch vụ chăm sóc khách hàng,Giấy phép hoạt động hợp pháp,Tốc độ trả thưởng nhanh)",
"Thủ tục đăng ký TDTC",
"Giới thiệu các trò chơi nổi bật của cổng game TDTC",
"Các chương trình khuyến mãi tại cổng game TDTC",
"Giải đáp những câu hỏi liên quan đến cổng game TDTC",
"Tổng kết về TDTC"
]
brand = "TDTC"
keyword = "TDTC"

# %%
outline_brand_8US= [
"Giới thiệu sơ lược về cổng game 8US",
"Đặc điểm nổi bật mà chỉ cổng game 8US mới có",
"Các điểm yếu mà 8US cần khắc phục",
"Giới thiệu các chương trình khuyến mãi cổng game 8US",
"Giải đáp những câu hỏi liên quan đến cổng game 8US",
"Tổng kết về cổng game 8US"
]
brand = "8US"
keyword = "8US"

# %%
outline_brand_top88= [
"Giới thiệu sơ lược về cổng game top88",
"Đặc điểm nổi bật mà chỉ cổng game top88 mới có",
"Các điểm yếu mà top88 cần khắc phục",
"Giới thiệu các chương trình khuyến mãi cổng game top88",
"Giải đáp những câu hỏi liên quan đến cổng game top88",
"Tổng kết về cổng game top88"
]
brand = "top88"
keyword = "cổng game top88"

# %%
outline_brand_B52= [
       'Giới thiệu chi tiết nhược điểm khi chơi casino trực tuyến tại 789 club: Hệ thống thường xuyên bảo tapoj; Cổng game chưa có chức năng phân loại khiến việc tìm kiếm trò chơi trở nên khó khăn hơn', 
       'Giới thiệu chi tiết ưu điểm khi chơi casino trực tuyến tại twin68: Chú trọng vào phát triển trò chơi game bài, casino trên di dộng; Quà tặng khủng khi tải app twin68 - tải app thành công nhận ngay 888k; Nạp rút tiền siêu tốc, siêu bảo mật',
       'Giới thiệu chi tiết nhược điểm khi chơi casino trực tuyến tại twin68: Không có cổng game online dành cho pc, chí có ứng dụng trên di động; Nhiều website mạo danh app twin68 để lừa đảo người chơi',
       'Giới thiệu chi tiết ưu điểm khi chơi casino trực tuyến tại v8 club: Bảo mật dữ liệu tuyệt đối thông qua các mã OTP; Chương trình khuyến mãi đa dạng: khuyến mãi cho tân thủ, tặng giftcode miễn phí, lì xì bất ngờ...; Kho game đồ sộ, lên đến con số hàng trăm tựa game',
       'Giới thiệu chi tiết nhược điểm khi chơi casino trực tuyến tại v8 club: Thường xuyên bị giả mạo của các website đối thủ; Nạp rút tiền siêu nhanh chỉ trong 2 phút; Thời gian phản hồi của đội ngũ CSKH tương đối lâu trong các giờ cao điểm']
keyword = 'casino trực tuyến'

# %%
outline_casino_trực_tuyến = ['Nhận xét chung về casino trực tuyến',
       'Giới thiệu chi tiết 20 ưu điểm khi chơi casino trực tuyến tại 8US',
       'Giới thiệu chi tiết 15 nhược điểm khi chơi casino trực tuyến tại 8US',
       'Giới thiệu chi tiết 20 ưu điểm khi chơi casino trực tuyến tại TDTC',
       'Giới thiệu chi tiết 15 nhược điểm khi chơi casino trực tuyến tại TDTC',
       'Giới thiệu chi tiết 20 ưu điểm khi chơi casino trực tuyến tại top88',
       'Giới thiệu chi tiết 15 nhược điểm khi chơi casino trực tuyến tại top88',
       'Giới thiệu chi tiết 20 ưu điểm khi chơi casino trực tuyến tại dwin68',
       'Giới thiệu chi tiết 15 nhược điểm khi chơi casino trực tuyến tại dwin68',
       'Giới thiệu chi tiết 20 ưu điểm khi chơi casino trực tuyến tại yo88',
       'Giới thiệu chi tiết 15 nhược điểm khi chơi casino trực tuyến tại yo88',
       'Giới thiệu chi tiết 20 ưu điểm khi chơi casino trực tuyến tại win79',
       'Giới thiệu chi tiết 15 nhược điểm khi chơi casino trực tuyến tại win79',
       'Giới thiệu chi tiết 20 ưu điểm khi chơi casino trực tuyến tại zowin',
       'Giới thiệu chi tiết 15 nhược điểm khi chơi casino trực tuyến tại zowin',
       'Giới thiệu chi tiết 20 ưu điểm khi chơi casino trực tuyến tại 789 club',
       'Giới thiệu chi tiết 15 nhược điểm khi chơi casino trực tuyến tại 789 club', 
       'Giới thiệu chi tiết 20 ưu điểm khi chơi casino trực tuyến tại twin68',
       'Giới thiệu chi tiết 15 nhược điểm khi chơi casino trực tuyến tại twin68',
       'Giới thiệu chi tiết 20 ưu điểm khi chơi casino trực tuyến tại v8 club',
       'Giới thiệu chi tiết 15 nhược điểm khi chơi casino trực tuyến tại v8 club',
       'Giới thiệu lịch sử của casino và quá trình phát triển của casino trực tuyến',
       'Những nguyên nhân khiến casino trực tuyến được đông đảo người chơi các cược yêu thích',
       'Các biến thể của casino trực tuyến',
       'Giới thiệu luật chơi casino trực tuyến',
       'Cách nhận biết các cổng game casino trực tuyến uy tín',
       'Kinh nghiệm chơi chơi casino trực tuyến hiệu quả mà mọi tân thủ cần phải biết',
       'Q&A: trả lời 10 câu hỏi về casino trực tuyến', 
       'Điều kiện để chơi casino trực tuyến theo đúng quy định của pháp luật',                     
       'Hướng dẫn cách đăng ký chơi casino trực tuyến',
       'Tổng kết về casino trực tuyến']
keyword = 'casino trực tuyến'

# %%
outline_game_bài_ăn_tiền2 = [
       'Giới thiệu chi tiết 10 nhược điểm của cổng game bắn cá đổi thưởng iWin68', 
       'Giới thiệu chi tiết 10 ưu điểm của cổng game bắn cá đổi thưởng YO88',
       'Giới thiệu chi tiết 10 nhược điểm của cổng bắn cá đổi thưởng game YO88',
       'Giới thiệu chi tiết 10 ưu điểm của cổng game bắn cá đổi thưởng Zowin',
       'Giới thiệu chi tiết 10 nhược điểm của cổng game bắn cá đổi thưởng Zowin',                              
       'Bắn cá đổi thưởng là gì, định nghĩa game bắn cá đổi thưởng',
       'Trình bày sơ lược nguồn gốc của game bắn cá đổi thưởng',
       '10 lí do vì sao nhiều người chơi bắn cá đổi thưởng',
       '10 tiêu chuẩn để lựa chọn cổng game bắn cá đổi thưởng uy tín, chất lượng cao',
       'Hướng dẫn nhận biết các cổng game bắn cá đổi thưởng lừa đảo',
       'Điểm tên các tựa game bắn cá đổi thưởng phổ biến',
       'Các thuật ngữ phổ biến khi chơi game bắn cá đổi thưởng',
       'Các thủ thuật chơi bắn cá đổi thưởng hiệu quả dành cho tân thủ',
       'Q&A: Giải đáp chi tiết 10 câu hỏi phổ biến về bắn cá đổi thưởng',
       'Hướng dẫn tổng quát cách đăng ký chơi bắn cá đổi thưởng',
       'Hướng dẫn tổng quát cách nạp rút tiền chơi bắn cá đổi thưởng',
       'Tổng kết về bắn cá đổi thưởng']
keyword = 'bắn cá đổi thưởng'

# %%
outline_cược_xiên_123B = [
    'Giới thiệu về cược xiên trong bóng đá',
    'Cược xiên là gì? Định nghĩa về cược xiên',
    'Ưu điểm và nhược điểm của đánh kèo cược xiên',
    'Các loại kèo cược xiên phổ biến',
    'Giới thiệu về kèo cược xiên châu Á, kèo cược xiên Châu Âu',
    'Công thức tính kèo cược xiên châu Âu, đưa ví dụ và công thức cụ thể',
    'Công thức tính kèo cược xiên châu Á, đưa ví dụ và công thức cụ thể',
    'Kinh nghiệm đánh kèo cược xiên an toàn và hiệu quả',
    'Tổng kết'
]
keyword = 'cược xiên 123B'
brand = '123B'

# %%
outline_cược_chấp_123B = [
    'Giới thiệu về kèo cược chấp trong bóng đá',
    'Các kèo cược chấp phổ biến',
    'Cách tính tiền thắng/thua trong kèo chấp 123B',
    'Mẹo chơi kèo chấp hiệu quả',
    'Lời khuyên cho game thủ để chơi kèo chấp an toàn, hiệu quả'
]

# %%
outline_cược_châu_á_123B = [
    'Giới thiệu về cược châu Á',
    'Các thể loại cược châu Á phổ biến nhất tại 123B',
    'Những ưu điểm của cược châu Á 123B',
    'Hướng dẫn cách tham gia cược châu Á 123B',
    'Tổng kết'
]
keyword = 'cược châu Á 123B'
brand = "123B"

# %%
keyword
# Out:
# 'cược xiên 123B'

# %%
df_bwing = pd.read_csv("data/bwing.csv")

# %%
df_bwing.head()
# Out:
#                                                  h/o header  \
# 0  H1: Bwing – Cập nhật link vào nhà cái Bwing tặ...     H1
# 1  H2: Giới thiệu nhà cái cá cược Bwing đẳng cấp ...     H2
# 2                                   H3: Bwing là gì?     H3
# 3  H3: Sự ra đời của Bwing và quá trình phát triể...     H3
# 4  H2: Điểm tên một số tên miền mở rộng mang thươ...     H2
#
#                                              outline  \
# 0   Bwing – Cập nhật link vào nhà cái Bwing tặng ...
# 1   Giới thiệu nhà cái cá cược Bwing đẳng cấp uy tín
# 2                                       Bwing là gì?
# 3   Sự ra đời của Bwing và quá trình phát triển t...
# 4   Điểm tên một số tên miền mở rộng mang thương ...
#
#                       requirement
# 0             Unique 95% trở lên
# 1  Văn phong mạch lạc rõ ràng
# 2                             NaN
# 3                             NaN
# 4                             NaN

# %% [markdown]
# df_bwing.outline.values

# %%
Nhà cái BK8 - Giá trị bền vững từ văn học Việt Nam
Đoạn mở bài (50-70 chữ)
H2: Tổng quan về nhà cái BK8 - Tình người giữa nạn đói năm 45 (vợ nhặt - kim lân)
H3 tự chế
H2: Giao dịch nạp rút tiền BK8 - Đồng tiền có làm tha hóa con người? ( Chí Phèo - Nam Cao)
H3 tự chế
H2: Tải app BK8 - Hi vọng giữa đêm đen (Vợ chồng A Phủ  - Tô Hoài)
H3 tự chế 
H2: Khuyến mại BK8 - Cơ hội của thời kì mới (Đoàn thuyền đánh cá - Huy Cận )
H3 tự chế
Kết luận (100 chữ)
# Out:
#   Input In [212]
#     Nhà cái BK8 - Giá trị bền vững từ văn học Việt Nam
#         ^
# SyntaxError: invalid syntax

# %%
outline_bk8=[
    'Giới thiệu sơ lược nhà cái BK8', #số đỏ
    'Tổng quan về nhà cái BK8', #vợ nhặt
    'Lịch sử hình thành nhà cái BK8',#số đỏ
    'Định hướng phát triển trong tương lai của BK8 ',#số đỏ
    'Những ưu điểm chỉ có tại BK8, liệt kê chi tiết',
    'Điều kiện để tham gia cá độ online tại BK8, liệt kê chi tiết',    
    'Giới thiệu quy trình nạp tiền BK8 (hướng dẫn từng bước một cách rõ ràng',
    'Hướng dẫn rút tiền BK8 (hướng dẫn từng bước một cách rõ ràng)',
    'Hướng dẫn tải app BK8 (bao gồm Android và iOS, hướng dẫn từng bước một cách rõ ràng)',
    'Tổng quan về nhà cái BK8'
]
keyword = 'BK8'

# %%
prompt_bk8.append(fist_element)

# %%
prompt_bk8 = []

for i in outline_bk8:
    prompt = 'Bạn là một nhà văn thiên tài. bạn có thể sáng tác được đủ các thể loại nội dung khác nhau.\
    bạn còn có khả năng bắt chước văn phong của các nhà văn khác của Việt Nam. \
    Bên cạnh đó, bạn cũng là một người am hiểu về lĩnh vực cá độ trực tuyến.\
    Dựa vào khả năng đó, hãy viêt một bài quảng cáo có nội dung {} nhưng theo phong cách của nhà văn Vũ Trong Phụng trong tác phẩm Số Đỏ. Bài viết sẽ phải có giọng văn châm biếm và hài hước.\
    Bài viết không được sử dụng tên nhân vật trong Số Đỏ hay nhắc đến "Số Đỏ" trong toàn bộ nội dung. \
    '.format(i)
    prompt_bk8.append(prompt)

# %%
prompts_casino_trực_tuyến2 = []
for i in outline_casino_trực_tuyến2:
    prompt = "Bạn là một chuyên gia về viết nội dung cho các website cá độ, đồng thời bạn cũng am hiểu về lĩnh vực cá độ trực tuyến.\
 Hãy viết một bài viết về nói về {}. Bài viết đó phải chứa từ khóa {}\
 và từ khóa phải xuất hiện ít nhất một lần. \
 Hãy sử dụng cấu trúc câu đa dạng, tránh trùng lặp.\
 Hãy đảm bảo rằng dung bài viết không ngắn hơn 300 chữ.\
 Giọng điệu chuyên nghiệp, tích cực.\
 ".format(i,keyword)
    prompts_casino_trực_tuyến2.append(prompt)

# %%
prompts_game_bài_ăn_tiền2 = []
for i in outline_game_bài_ăn_tiền2:
    prompt = "Bạn là một chuyên gia về viết nội dung cho các website cá độ, đồng thời bạn cũng am hiểu về lĩnh vực cá độ trực tuyến.\
 Hãy viết một bài viết về nói về {}. Bài viết đó phải chứa từ khóa {}\
 và từ khóa phải xuất hiện ít nhất một lần. \
 Hãy sử dụng cấu trúc câu đa dạng, tránh trùng lặp.\
 Hãy đảm bảo rằng dung bài viết không ngắn hơn 300 chữ.\
 Giọng điệu chuyên nghiệp, tích cực.\
 ".format(i,keyword)
    prompts_game_bài_ăn_tiền2.append(prompt)

# %%
prompt_bắn_cá_đổi_thưởng_2 = []
for i in outline_bắn_cá_đổi_thưởng_2:
    prompt = "Bạn là một chuyên gia về viết nội dung cho các website cá độ, đồng thời bạn cũng am hiểu về lĩnh vực cá độ trực tuyến.\
 Hãy viết một bài viết về nói về {}. Bài viết đó phải chứa từ khóa {}\
 và từ khóa phải xuất hiện ít nhất một lần. \
 Hãy sử dụng cấu trúc câu đa dạng, tránh trùng lặp.\
 Hãy đảm bảo rằng dung bài viết không ngắn hơn 400 chữ.\
 Giọng điệu chuyên nghiệp, tích cực.\
 ".format(i,keyword)
    prompt_bắn_cá_đổi_thưởng_2.append(prompt)

# %%
prompt_bắn_cá_đổi_thưởng_2[6]
# Out:
# 'Bạn là một chuyên gia về viết nội dung cho các website cá độ, đồng thời bạn cũng am hiểu về lĩnh vực cá độ trực tuyến. Hãy viết một bài viết về nói về Giới thiệu chi tiết ưu điểm của cổng game bắn cá đổi thưởng B52 bao gồm (1: Jackpot cho game bắn cá đổi thưởng lên đến 417.000.000 đồng, 2: Nạp rút tiền siêu tiện lợi, hỗ trợ nạp rút từ nhiều ngân hàng, 3: Số lượng game bắn cá đa dạng). Bài viết đó phải chứa từ khóa bắn cá đổi thưởng và từ khóa phải xuất hiện ít nhất một lần.  Hãy sử dụng cấu trúc câu đa dạng, tránh trùng lặp. Hãy đảm bảo rằng dung bài viết không ngắn hơn 400 chữ. Giọng điệu chuyên nghiệp, tích cực. '

# %%
prompts_nổ_hũ_đổi_thưởng_2 = []
for i in outline_nổ_hũ_đổi_thưởng_2:
    prompt = "Bạn là một chuyên gia về viết nội dung cho các website cá độ, đồng thời bạn cũng am hiểu về lĩnh vực cá độ trực tuyến.\
 Hãy viết một bài viết về nói về {}. Bài viết đó phải chứa từ khóa {}\
 và từ khóa phải xuất hiện ít nhất một lần. \
 Hãy sử dụng cấu trúc câu đa dạng, tránh trùng lặp.\
 Hãy đảm bảo rằng dung bài viết không ngắn hơn 400 chữ.\
 Giọng điệu chuyên nghiệp, tích cực.\
 ".format(i,keyword)
    prompts_nổ_hũ_đổi_thưởng_2.append(prompt)

# %%
prompts_casino_trực_tuyến = []
for i in outline_casino_trực_tuyến:
    prompt = "Bạn là một chuyên gia về viết nội dung cho các website cá độ, đồng thời bạn cũng am hiểu về lĩnh vực cá độ trực tuyến.\
 Hãy viết một bài viết về nói về {}. Bài viết đó phải chứa từ khóa {}\
 và từ khóa phải xuất hiện ít nhất một lần. \
 Hãy sử dụng cấu trúc câu đa dạng, tránh trùng lặp.\
 Hãy đảm bảo rằng dung bài viết không ngắn hơn 600 chữ.\
 Giọng điệu chuyên nghiệp, tích cực.\
 ".format(i,keyword)
    prompts_casino_trực_tuyến.append(prompt)

# %%
prompts_game_bài_ăn_tiền = []
for i in outline_game_bài_ăn_tiền:
    prompt = "Bạn là một chuyên gia về viết nội dung cho các website cá độ, đồng thời bạn cũng am hiểu về lĩnh vực cá độ trực tuyến.\
 Hãy viết một bài viết về nói về {}. Bài viết đó phải chứa từ khóa {}\
 và từ khóa phải xuất hiện ít nhất một lần. \
 Hãy sử dụng cấu trúc câu đa dạng, tránh trùng lặp.\
 Hãy đảm bảo rằng dung bài viết không ngắn hơn 600 chữ.\
 Giọng điệu chuyên nghiệp, tích cực.\
 ".format(i,keyword)
    prompts_game_bài_ăn_tiền.append(prompt)

# %%
outline_brand_TDTC
prompts_TDTC = []
for i in outline_brand_TDTC:
    prompt = "Bạn là một chuyên gia về viết nội dung cho các website cá độ, đồng thời bạn cũng am hiểu về lĩnh vực cá độ trực tuyến.\
 Hãy viết một bài viết về nói về {}. Bài viết đó phải chứa từ khóa {}\
 và từ khóa phải xuất hiện ít nhất một lần và nội dung bài viết phải liên quan đến thương hiệu {}.\
 Hãy sử dụng cấu trúc câu đa dạng, tránh trùng lặp.\
 Hãy đảm bảo rằng dung bài viết không ngắn hơn 500 chữ.\
 Giọng điệu chuyên nghiệp, tích cực. Nội dung phải đáp ứng được các tiêu chuẩn của SEO.\
 ".format(i,keyword,brand)
    prompts_TDTC.append(prompt)

# %%
outline_brand_8US
prompts_8US = []
for i in outline_brand_8US:
    prompt = "Bạn là một chuyên gia về viết nội dung cho các website cá độ, đồng thời bạn cũng am hiểu về lĩnh vực cá độ trực tuyến.\
 Hãy viết một bài viết về nói về {}. Bài viết đó phải chứa từ khóa {}\
 và từ khóa phải xuất hiện ít nhất một lần và nội dung bài viết phải liên quan đến thương hiệu {}.\
 Hãy sử dụng cấu trúc câu đa dạng, tránh trùng lặp.\
 Hãy đảm bảo rằng dung bài viết không ngắn hơn 600 chữ.\
 Giọng điệu chuyên nghiệp, tích cực. Nội dung phải đáp ứng được các tiêu chuẩn của SEO.\
 ".format(i,keyword,brand)
    prompts_8US.append(prompt)

# %%
outline_brand_8US
prompts_8US = []
for i in outline_brand_8US:
    prompt = "Bạn là một chuyên gia về viết nội dung cho các website cá độ, đồng thời bạn cũng am hiểu về lĩnh vực cá độ trực tuyến.\
 Hãy viết một bài viết về nói về {}. Bài viết đó phải chứa từ khóa {}\
 và từ khóa phải xuất hiện ít nhất một lần và nội dung bài viết phải liên quan đến thương hiệu {}.\
 Hãy sử dụng cấu trúc câu đa dạng, tránh trùng lặp.\
 Hãy đảm bảo rằng dung bài viết không ngắn hơn 500 chữ.\
 Giọng điệu chuyên nghiệp, tích cực. Nội dung phải đáp ứng được các tiêu chuẩn của SEO.\
 ".format(i,keyword,brand)
    prompts_8US.append(prompt)

# %%
prompts_top88 = []
for i in outline_brand_top88:
    prompt = "Bạn là một chuyên gia về viết nội dung cho các website cá độ, đồng thời bạn cũng am hiểu về lĩnh vực cá độ trực tuyến.\
 Hãy viết một bài viết về nói về {}. Bài viết đó phải chứa từ khóa {}\
 và từ khóa phải xuất hiện ít nhất một lần và nội dung bài viết phải liên quan đến thương hiệu {}.\
 Hãy sử dụng cấu trúc câu đa dạng, tránh trùng lặp.\
 Hãy đảm bảo rằng dung bài viết không ngắn hơn 500 chữ.\
 Giọng điệu chuyên nghiệp, tích cực. Nội dung phải đáp ứng được các tiêu chuẩn của SEO.\
 ".format(i,keyword,brand)
    prompts_top88.append(prompt)

# %%
prompts_B52 = []
for i in outline_brand_B52:
    prompt = "Bạn là một chuyên gia về viết nội dung cho các website cá độ, đồng thời bạn cũng am hiểu về lĩnh vực cá độ trực tuyến.\
 Hãy viết một bài viết về nói về {}. Bài viết đó phải chứa từ khóa {}\
 và từ khóa phải xuất hiện ít nhất một lần và nội dung bài viết phải liên quan đến thương hiệu {}.\
 Hãy sử dụng cấu trúc câu đa dạng, tránh trùng lặp.\
 Hãy đảm bảo rằng dung bài viết không ngắn hơn 500 chữ.\
 Giọng điệu chuyên nghiệp, tích cực. Nội dung phải đáp ứng được các tiêu chuẩn của SEO.\
 ".format(i,keyword,brand)
    prompts_B52.append(prompt)

# %%
#outline_bắn_cá_đổi_thưởng
prompts_bắn_cá_đổi_thưởng = []
for i in outline_bắn_cá_đổi_thưởng:
    prompt = "Bạn là một chuyên gia về viết nội dung cho các website cá độ, đồng thời bạn cũng am hiểu về lĩnh vực cá độ trực tuyến.\
 Hãy viết một bài viết về nói về {}. Bài viết đó phải chứa từ khóa {}\
 và từ khóa phải xuất hiện ít nhất một lần \
 Hãy sử dụng cấu trúc câu đa dạng, tránh trùng lặp.\
 Hãy đảm bảo rằng dung bài viết không ngắn hơn 500 chữ.\
 Giọng điệu chuyên nghiệp, tích cực.\
 ".format(i,keyword)
    prompts_bắn_cá_đổi_thưởng.append(prompt)

# %%
#outline_nổ_hũ_đổi_thưởng
prompts_nổ_hũ_đổi_thưởng = []
for i in outline_nổ_hũ_đổi_thưởng:
    prompt = "Bạn là một chuyên gia về viết nội dung cho các website cá độ, đồng thời bạn cũng am hiểu về lĩnh vực cá độ trực tuyến.\
 Hãy viết một bài viết về nói về {}. Bài viết đó phải chứa từ khóa {}\
 và từ khóa phải xuất hiện ít nhất một lần. \
 Hãy sử dụng cấu trúc câu đa dạng, tránh trùng lặp.\
 Hãy đảm bảo rằng dung bài viết không ngắn hơn 500 chữ.\
 Giọng điệu chuyên nghiệp, tích cực.\
 ".format(i,keyword)
    prompts_nổ_hũ_đổi_thưởng.append(prompt)

# %%
prompts_cược_xiên_123B = []
for i in outline_cược_xiên_123B:
    prompt = "Bạn là một chuyên gia về viết nội dung cho các website cá độ, đồng thời bạn cũng am hiểu về các loại kèo cược cá độ trực tuyến.\
 Hãy viết một bài viết về nói về {}. Bài viết đó phải chứa từ khóa '{}'\
 và từ khóa này phải xuất hiện ít nhất một lần. Nội dung bài viết phải liên quan đến thương hiệu {}. \
 Hãy sử dụng cấu trúc câu đa dạng, tránh trùng lặp.\
 Hãy đảm bảo rằng dung bài viết không ngắn hơn 400 chữ.\
 Giọng điệu chuyên nghiệp, tích cực.\
 ".format(i,keyword,brand)
    prompts_cược_xiên_123B.append(prompt)

# %%
prompts_cược_châu_á_123B = []
for i in outline_cược_châu_á_123B:
    prompt = "Bạn là một chuyên gia về viết nội dung cho các website cá độ, đồng thời bạn cũng am hiểu về các loại kèo cược cá độ bóng đá trực tuyến.\
 Hãy viết một bài viết về nói về {}. Bài viết đó phải có sự xuất hiện của từ khóa '{}' ít nhất 3 lần.\
 Nội dung bài viết phải liên quan đến thương hiệu {}.\
 Hãy sử dụng cấu trúc câu đa dạng, tránh trùng lặp.\
 Hãy đảm bảo rằng dung bài viết không ngắn hơn 400 chữ.\
 Giọng điệu chuyên nghiệp, tích cực.\
 ".format(i,keyword,brand)
    prompts_cược_châu_á_123B.append(prompt)

# %%
len(prompts_cược_xiên_123B)
# Out:
# 9

# %%
prompts_cược_châu_á_123B
# Out:
# ["Bạn là một chuyên gia về viết nội dung cho các website cá độ, đồng thời bạn cũng am hiểu về các loại kèo cược cá độ bóng đá trực tuyến. Hãy viết một bài viết về nói về Giới thiệu về cược châu Á. Bài viết đó phải có sự xuất hiện của từ khóa 'cược châu Á 123B' ít nhất 3 lần. Nội dung bài viết phải liên quan đến thương hiệu 123B. Hãy sử dụng cấu trúc câu đa dạng, tránh trùng lặp. Hãy đảm bảo rằng dung bài viết không ngắn hơn 400 chữ. Giọng điệu chuyên nghiệp, tích cực. ",
#  "Bạn là một chuyên gia về viết nội dung cho các website cá độ, đồng thời bạn cũng am hiểu về các loại kèo cược cá độ bóng đá trực tuyến. Hãy viết một bài viết về nói về Các thể loại cược châu Á phổ biến nhất tại 123B. Bài viết đó phải có sự xuất hiện của từ khóa 'cược châu Á 123B' ít nhất 3 lần. Nội dung bài viết phải liên quan đến thương hiệu 123B. Hãy sử dụng cấu trúc câu đa dạng, tránh trùng lặp. Hãy đảm bảo rằng dung bài viết không ngắn hơn 400 chữ. Giọng điệu chuyên nghiệp, tích cực. ",
# ...

# %%
for i in range(0, len(prompts_cược_châu_á_123B)):
    print('##'+outline_cược_châu_á_123B[i],'\n')
    fill_prompt(prompts_cược_châu_á_123B[i])
# Out:
# ##Giới thiệu về cược châu Á
#
# Chinh phục thị trường cá độ với Cược Châu Á 123B: Hướng dẫn thú vị cho người chơi
# Trong hành trình đầy thách thức của người yêu thích cá độ bóng đá trực tuyến, cược châu Á luôn nổi bật như một lựa chọn tinh tế, và thương hiệu uy tín 123B không chỉ là người bạn đồng hành đáng tin cậy, mà còn đem đến cơ hội đầy hứa hẹn. Với tầm hiểu biết sâu rộ về cược châu Á, hãy cùng chúng tôi khám phá ngay những điều thú vị mà hình thức cược này mang lại.
# 1. Cược châu Á 123B - Hấp dẫn với tính cách riêng
# Cược châu Á 123B không chỉ đơn thuần là một hình thức đặt cược, mà còn là một trải nghiệm tinh tế đem lại cảm xúc khác biệt. Với cách thức đặt cược độc đáo, người chơi không chỉ đặt tiền vào kết quả trận đấu, mà còn phải đánh giá mức chênh lệch giữa hai đội bóng. Điều này đồng nghĩa với việc cơ hội chiến thắng luôn đè nặng về phía người chơi thông qua những phân tích tỷ lệ châu Á chính xác.
# 2. 123B - Đối tác đáng tin cậy của người chơi cược châu Á
# ...

# %%
for i in range(0, len(prompts_cược_xiên_123B)):
    print('##'+outline_cược_xiên_123B[i],'\n')
    fill_prompt(prompts_cược_xiên_123B[i])
# Out:
# ##Giới thiệu về cược xiên trong bóng đá
#
# Tiêu đề: Giới thiệu về Cược Xiên trong Bóng Đá và Sự Kết Hợp Hấp Dẫn tại 123B
# Trong thế giới sôi động của cá cược bóng đá trực tuyến, Cược Xiên đã trở thành một lựa chọn hấp dẫn đối với những người yêu thích sự thách thức và muốn tận hưởng cảm giác thăng hoa từ những trận đấu đỉnh cao. Với sự kết hợp uyển chuyển giữa cả hai trận đấu, Cược Xiên không chỉ mang đến cơ hội kiếm lời hấp dẫn mà còn là cách tuyệt vời để thể hiện sự am hiểu về bóng đá. Và bạn có thể tận hưởng trải nghiệm này một cách tốt nhất tại 123B - một thương hiệu uy tín trong làng cá cược trực tuyến.
# 1. Cược Xiên là gì?
# Cược Xiên là sự kết hợp của hai kèo cược độc lập trên hai trận đấu khác nhau trong cùng một vé cược. Điều này có nghĩa là bạn phải dự đoán kết quả của cả hai trận đấu để thắng cược. Điều này đòi hỏi người chơi phải có sự am hiểu về các đội bóng, phong độ cũng như các yếu tố khác nhau có thể ảnh hưởng đến kết quả.
# 2. Sự hấp dẫn của Cược Xiên tại 123B
# ...

# %%
for i in range(0, len(prompt_bắn_cá_đổi_thưởng_2)):
    print('###'+outline_bắn_cá_đổi_thưởng_2[i],'\n')
    fill_prompt(prompt_bắn_cá_đổi_thưởng_2[i])
# Out:
# ###Giới thiệu chi tiết ưu điểm của cổng game bắn cá đổi thưởng TDTC bao gồm (1 giao diện bắt mắt, âm thanh sống động, gây ấn tượng với người chơi, 2: tặng tiền thưởng ngay khi đăng ký thành công, 3: số lượng bắn cá đổi thưởng đa dạng theo từng cấp độ, 4:Chế độ chơi thử cho phép người chơi làm quen với game trước khi nạp tiền chơi thật , 5: Nạp rút tiền siêu tốc, chấp nhận mọi hình thức thanh toán từ chuyển khoảng ngân hàng, ví điện từ, thẻ cào đến giftcode)
#
# Tiêu đề: Khám phá Ưu Điểm Tuyệt Vời của Cổng Game Bắn Cá Đổi Thưởng TDTC
# Trong thế giới sôi động của các trò chơi cá độ trực tuyến, cổng game bắn cá đổi thưởng TDTC nổi bật như một ngôi sao sáng rực rỡ. Với một loạt các ưu điểm vượt trội, TDTC không chỉ đem lại niềm vui giải trí mà còn mang đến những trải nghiệm độc đáo cho người chơi. Dưới đây là một số điểm nổi bật đầy hấp dẫn của TDTC.
# 1. Giao Diện Bắt Mắt và Âm Thanh Sống Động:
# ...

# %%
for i in range(0, len(prompts_nổ_hũ_đổi_thưởng_2)):
    print('###'+outline_nổ_hũ_đổi_thưởng_2[i],'\n')
    fill_prompt(prompts_nổ_hũ_đổi_thưởng_2[i])
# Out:
# ###Giới thiệu chi tiết ưu điểm của cổng game nổ hũ đổi thưởng TDTC bao gồm (1 giao diện bắt mắt, âm thanh sống động, có độ tương tác cao, 2: tặng tiền thưởng ngay khi đăng ký thành công, 3: số lượng game nổ hũ đổi thưởng đa dạng, bao gồm cả các mini game hấp dẫn, 4: jackpot khủng, giải lưởng lên đến hơn 8.500.000 đồng, 5: nạp rút tiền đơn giản, chấp nhận mọi hình thức thanh toán từ chuyển khoảng ngân hàng, ví điện từ, thẻ cào đến giftcode)
#
# Nổ Hũ Đổi Thưởng TDTC - Khám Phá Nhiều Ưu Điểm Hấp Dẫn
# Trong thế giới sôi động của cá độ trực tuyến, Cổng game nổ hũ đổi thưởng TDTC đã nhanh chóng thu hút sự quan tâm của người chơi bởi những ưu điểm vượt trội mà nó mang lại. Hãy cùng khám phá về những đặc điểm nổi bật mà TDTC mang đến.
# 1. Giao Diện Bắt Mắt và Âm Thanh Sống Động
# ...

# %%
for i in range(0, len(prompt_bk8)):
    print('##'+outline_bk8[i],'\n','_______________________________________________')
    fill_prompt(prompt_bk8[i])
# Out:
# ##Giới thiệu sơ lược nhà cái BK8
#  _______________________________________________
# Từ người chưa từng rong chơi với cá độ, đến những con người vẫn còn giữ đôi đồng xanh trong túi quần, hãy lắng nghe câu chuyện của nhà cái BK8, nơi mà tiền tài và may mắn đấu tranh trong một vũ trụ giả tưởng đầy bất ngờ.
# Như những chiếc lá đổ rơi mỗi ngày mùa thu, câu chuyện của BK8 lan tỏa như một trò đùa đầy thách thức. Để có thể theo đuổi niềm vui cá cược, họ đã mạo hiểm vào thế giới của số phận, nơi mà cuộc đời chính là bản nhạc khác biệt từng ngày. Từng bước chân vội vã đặt lên sân cỏ ảo, họ đã được chào đón bởi những cơ hội đang bất chấp núi rừng, đang tìm cách ẩn mình trong bóng tối.
# Như những nhân vật nổi tiếng trong tác phẩm của Vũ Trọng Phụng, BK8 xuất hiện như một hình ảnh đầy bí ẩn, khiến người ta không thể không nhắm mắt và mơ màng. Có lẽ họ là người hùng của cuộc phiêu lưu đen tối, hay cũng có thể chỉ là những kẻ mơ mộng vượt qua ranh giới thực tế.
# ...

# %%
for i in range(0, len(prompts_casino_trực_tuyến2)):
    print('###'+outline_casino_trực_tuyến2[i],'\n')
    fill_prompt(prompts_casino_trực_tuyến2[i])
# Out:
# ###Giới thiệu chi tiết ưu điểm khi chơi casino trực tuyến tại 8US: Kết hợp với nền nhiều nên tảng live casino nổi tiếng như AG, BBin, AWC để mang đến trải nghiệm tốt nhất cho người chơi; Sảnh casino online có quy mô khủng, đa dạng hình thức chơi như Baccarat, Rồng Hổ, Roulette, Blackjack; Giàn dealer sexy và chuyên nghiệp, hỗ trợ người chơi tận tình trong suốt quá trình chơi;Giải đấu casino thường niên "The glorious return of the top Master" có tổng giá trị giải thưởng lên đến 1.800.000 USD
#
# Khám Phá Ưu Điểm Hấp Dẫn Khi Chơi Casino Trực Tuyến Tại 8US
# Casino trực tuyến đã trở thành một phần quan trọng trong thế giới cá độ, và 8US là một trong những nền tảng hàng đầu mang đến trải nghiệm tuyệt vời cho người chơi. Dưới đây là những ưu điểm nổi bật khi tham gia chơi casino tại 8US:
# 1. Sự Kết Hợp Đa Dạng Với Các Nền Tảng Live Casino
# ...

# %%
for i in range(0, len(prompts_game_bài_ăn_tiền2)):
    print('###'+outline_game_bài_ăn_tiền2[i],'\n')
    fill_prompt(prompts_game_bài_ăn_tiền2[i])
# Out:
# ###Giới thiệu chi tiết ưu điểm khi chơi game bài ăn tiền tại 8US bao gồm: Cổng game đầu tư mạnh mẽ vào các game bài hot nhất như phỏm, tiến lên miền Nam và các biến thể Poker; Nhiều ưu đãi khủng như quà thưởng VIP lên đến 2300K, thưởng nạp lên đến 888K, quà lì xì bất ngờ; Tiền hoa hồng hậu hĩnh cho đại lý tỉ lệ theo tổng cược và cấp độ người chơi; Quy trình nạp rút tiền nhanh gọn, bảo mật, đa dạng, hỗ trợ phần lớn các ngân hàng tại Việt Nam; Bộ phận chăm sóc khách hàng hỗ trợ người chơi 24/7, phản hồi ngay lập tức khi có yêu cầu từ người chơi
#
# Nhấn Điểm Mạnh Khi Tham Gia Game Bài ăn Tiền tại 8US
# Trong thế giới sôi động của cá độ trực tuyến, 8US nổi bật với hàng loạt ưu điểm đáng chú ý khiến người chơi không thể bỏ qua. Hãy cùng khám phá những điểm mạnh độc đáo khi tham gia trải nghiệm game bài ăn tiền tại sòng bạc này.
# 1. Các Game Bài Hot Và Đa Dạng
# ...

# %%
for i in range(0, len(prompts_nổ_hũ_đổi_thưởng_2)):
    print('###'+outline_nổ_hũ_đổi_thưởng_2[i],'\n','_______________________________________________')
    fill_prompt(prompts_nổ_hũ_đổi_thưởng_2[i])
# Out:
# ###Giới thiệu chi tiết ưu điểm của cổng game nổ hũ đổi thưởng TDTC bao gồm (1 giao diện bắt mắt, âm thanh sống động, có độ tương tác cao, 2: tặng tiền thưởng ngay khi đăng ký thành công, 3: số lượng game nổ hũ đổi thưởng đa dạng, bao gồm cả các mini game hấp dẫn, 4: jackpot khủng, giải lưởng lên đến hơn 8.500.000 đồng, 5: nạp rút tiền đơn giản, chấp nhận mọi hình thức thanh toán từ chuyển khoảng ngân hàng, ví điện từ, thẻ cào đến giftcode)
#  _______________________________________________
# Nổ Hũ Đổi Thưởng TDTC: Khám Phá Kho Tàng Ưu Điểm Tuyệt Vời
# Trong thế giới sôi động của cá độ trực tuyến, cổng game nổ hũ đổi thưởng TDTC đã nổi lên như một ngôi sao sáng, thu hút sự chú ý của hàng ngàn người chơi. Với một loạt ưu điểm độc đáo, TDTC không chỉ là nơi thỏa mãn niềm đam mê cá độ mà còn là nguồn giải trí đỉnh cao mà bạn không thể bỏ qua.
# ...

# %%
for i in range(0, len(prompts_casino_trực_tuyến)):
    print('##'+outline_casino_trực_tuyến[i],'\n','_______________________________________________')
    fill_prompt(prompts_casino_trực_tuyến[i])
# Out:
# ##Nhận xét chung về casino trực tuyến
#  _______________________________________________
# Tiêu dùng giải trí trực tuyến đã có một sự phát triển mạnh mẽ trong những năm gần đây, và casino trực tuyến đã nhanh chóng trở thành một phần quan trọng của thế giới giải trí kỹ thuật số. Việc tham gia vào các trò chơi casino trực tuyến không chỉ mang đến cho người chơi những trải nghiệm thú vị, mà còn mở ra những cơ hội giành được những phần thưởng hấp dẫn.
# Sự Đa Dạng và Tiện Lợi
# Một điểm thuận lợi nổi bật của casino trực tuyến là sự đa dạng về lựa chọn trò chơi. Từ các trò máy đánh bạc kinh điển đến bàn poker hấp dẫn, người chơi có cơ hội trải nghiệm một loạt các trò chơi đa dạng và hấp dẫn. Sự tiện lợi cũng là một yếu tố quan trọng khiến casino trực tuyến trở thành sự lựa chọn hàng đầu. Người chơi có thể tham gia vào các trò chơi yêu thích của họ bất cứ lúc nào và ở bất kỳ đâu, chỉ cần một kết nối internet.
# Trải Nghiệm Thực Tế Tại Nhà
# ...

# %%
for i in range(0, len(prompts_game_bài_ăn_tiền)):
    print('##'+outline_game_bài_ăn_tiền[i],'\n','_______________________________________________')
    fill_prompt(prompts_game_bài_ăn_tiền[i])
# Out:
# ##nhận xét chung về game bài ăn tiền
#  _______________________________________________
# Tiêu Đề: Game Bài Ăn Tiền: Sự Kết Hợp Hoàn Hảo Giữa Giải Trí và Thử Thách Tài Năng
# Trong thế giới phong phú của ngành công nghiệp cá độ trực tuyến, game bài ăn tiền đã từ lâu thu hút sự chú ý của đại đa số người chơi. Được tạo ra với mục tiêu kết hợp giữa niềm vui giải trí và thử thách tài năng, các loại game này đã chứng tỏ là một phần không thể thiếu trong thế giới giải trí trực tuyến ngày nay.
# Sự Đa Dạng và Cân Nhắc Kỹ Lưỡng
# Tính đa dạng là điểm mạnh của game bài ăn tiền. Không chỉ đơn thuần là việc đặt cược, mà mỗi game bài mang trong mình một cốt truyện và cách chơi riêng biệt. Người chơi có thể lựa chọn từ một loạt các trò như Poker, Baccarat, Blackjack, và nhiều game khác. Sự cân nhắc kỹ lưỡng trong việc chọn game phù hợp với tài năng và sở thích cá nhân là một bước quan trọng để đảm bảo trải nghiệm chơi tốt nhất.
# Thách Thức Tài Năng và Chiến Lược
# ...

# %%
for i in range(0, len(prompts_nổ_hũ_đổi_thưởng)):
    print('##'+outline_nổ_hũ_đổi_thưởng[i],'\n','_______________________________________________')
    fill_prompt(prompts_nổ_hũ_đổi_thưởng[i])
# Out:
# ##nhận xét chung về game nổ hũ đổi thưởng
#  _______________________________________________
# Nhận Xét Chung Về Game Nổ Hũ Đổi Thưởng: Sự Kết Hợp Hấp Dẫn Giữa May Mắn Và Giải Trí
# Trong thế giới sôi động của cá độ trực tuyến, game nổ hũ đổi thưởng đã từ lâu trở thành một phần không thể thiếu của trải nghiệm giải trí và cơ hội thử vận may. Được đánh giá là một biểu tượng của sự phấn khích và thách thức, game nổ hũ đổi thưởng luôn thu hút sự quan tâm của hàng triệu người chơi khắp nơi. Dưới đây là một số nhận xét chung về thế giới đa dạng và hấp dẫn của trò chơi này:
# 1. Sự Kết Hợp Giữa May Mắn Và Kỹ Năng:
# Game nổ hũ đổi thưởng là sự kết hợp tinh tế giữa yếu tố may mắn và kỹ năng. Người chơi có thể dựa vào may mắn để giành được những phần thưởng giá trị, nhưng cũng cần có sự tinh thông và tính toán để chọn cách chơi phù hợp.
# 2. Sự Đa Dạng Về Chủ Đề Và Đồ Họa:
# ...

# %%
for i in range(0, len(prompts_đá_gà_123B)):
    print(outline_đá_gà_123B[i]+'\n')
    print('({:0.2f}% completed!)'.format(100*(i+1)/len(prompts_đá_gà_123B)),'\n_______________________________________________')
    scan_all_results(prompts_đá_gà_123B[i])
    html_element = driver.find_element(By.TAG_NAME,'html')
    html_element.send_keys(Keys.END)
time.sleep(20)
section = driver.find_element(By.XPATH, '//*[@id="__next"]/div[1]/div[2]/div/main/div[1]/div/div/div')
articles = section.find_elements(By.CLASS_NAME,"bg-gray-50")
for i in range(0, len(articles)):
    print('\n'+'##'+outline_đá_gà_123B[i],'\n-----------------')
    print(articles[i].text)
# Out:
# giới thiệu về sảnh đá gà 123B (phải đề cập đến đá gà 123B có 2 sảnh là Digmaan và WS 168 Gaming hiện tại chính là hai trường đá gà lớn nhất tại Philippin)
#
# (14.29% completed!)
# _______________________________________________
# các ưu điểm chỉ có tại sảnh đá gà 123B
#
# (28.57% completed!)
# _______________________________________________
# giới thiệu các chương trình khuyến mãi khi chơi đá gà 123B, bao gồm (khuyến mãi hoàn cược lên đến 2%, khuyến mãi tặng quà sinh nhật khủng, khuyến mãi tặng ngay 100k khi đăng ký hoặc tải app, nhận tiền thưởng khi giới thiệu bạn bè, phần thưởng gặp mặt lên đến 21.000.000 đồng khi đổi nhà cái đến với 123B )
#
# (42.86% completed!)
# _______________________________________________
# Điều kiện để tham giá các cược cá gà 123B
#
# (57.14% completed!)
# _______________________________________________
# Hướng dẫn đăng ký đá gà 123B
#
# (71.43% completed!)
# _______________________________________________
# Những điều cần lưu ý khi tham gia đá gà 123B
#
# ...

# %%
for i in range(0, len(prompts_bắn_cá_đổi_thưởng)):
    print('##'+outline_bắn_cá_đổi_thưởng[i],'\n','_______________________________________________')
    fill_prompt(prompts_bắn_cá_đổi_thưởng[i])

# %%
for i in range(0, len(prompts_bắn_cá_đổi_thưởng)):
    print('##'+outline_bắn_cá_đổi_thưởng[i],'\n','_______________________________________________')
    fill_prompt(prompts_bắn_cá_đổi_thưởng[i])
# Out:
# ##nhận xét chung về game bắn cá đổi thưởng
#  _______________________________________________
# Bắn Cá Đổi Thưởng: Dòng Game Sôi Động Trong Thế Giới Cá Độ Trực Tuyến
Bwing07 là một tên miền mở rộng khác mang thương hiệu Bwing. "07" có thể ám chỉ một lựa chọn hàng đầu, và Bwing07 thể hiện sự cam kết của nhà cái này đem đến trải nghiệm cá cược tốt nhất cho người chơi. Tên miền này giúp người chơi dễ dàng tiếp cận các trò chơi cá độ và casino trực tuyến đa dạng mà Bwing cung cấp.
6. Bwing16
Bwing16 là một tên miền mở rộng khác mang thương hiệu Bwing. "16" có thể liên kết với số may mắn và thịnh vượng. Bằng cách truy cập vào Bwing16, người chơi có cơ hội trải nghiệm các trò chơi cá độ thú vị và các dịch vụ casino chất lượng mà Bwing cung cấp.
Kết luận
Như vậy, những tên miền mở rộng Bwing.me, Bwing88, Bwing.cm, Bwing02, Bwing07 và Bwing16 đều là những lựa chọn tốt và tiện lợi cho người chơi yêu thích cá độ và casino trực tuyến. Với đa dạng sản phẩm, giao diện thân thiện và cam kết uy tín, Bwing tiếp tục khẳng định vị thế là một trong những nhà cái hàng đầu trong lĩnh vực cá độ trực tuyến và thu hút được sự tin tưởng của đông đảo người chơi. Hãy khám phá và tham gia ngay các tên miền Bwing để trải nghiệm những khoảnh khắc thú vị và thách thức bản thân trong thế giới cá cược đa dạng và phong phú.
ID,'prompt-textarea')

# %%
prompt_field.clear()
prompt_field.send_keys(prompts[0])

# %%
//*[@id="__next"]/div[1]/div[2]/div/main/div[2]/form/div/div[2]/button

# %%
enter_prompt_btn = driver.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[2]/div/main/div[2]/form/div/div[2]/button')

# %%
driver.execute_script ("arguments[0].click();",enter_prompt_btn)

# %%
<button class="btn relative btn-neutral -z-0 border-0 md:border" as="button"><div class="flex w-full gap-2 items-center justify-center"><svg stroke="currentColor" fill="none" stroke-width="1.5" viewBox="0 0 24 24" stroke-linecap="round" stroke-linejoin="round" class="h-3 w-3 flex-shrink-0" height="1em" width="1em" xmlns="http://www.w3.org/2000/svg"><polyline points="1 4 1 10 7 10"></polyline><polyline points="23 20 23 14 17 14"></polyline><path d="M20.49 9A9 9 0 0 0 5.64 5.64L1 10m22 4l-4.64 4.36A9 9 0 0 1 3.51 15"></path></svg>Regenerate response</div></button>

# %%
def fill_prompt(prompt):
    prompt_field =  driver.find_element(By.ID,'prompt-textarea')
    prompt_field.clear()
    #send prompt to textarea
    prompt_field.send_keys(prompt)
    #enter to write content
    enter_btn = prompt_field.find_element(By.XPATH, "following-sibling::*[1]")
    if enter_btn.is_enabled():
        driver.execute_script ("arguments[0].click();",enter_btn)
        time.sleep(40)
        #buttone where we can click to regenerate respnse or stop regenerate or continue:
        buttons_container_div =  driver.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[2]/div/main/div[2]/form/div/div[1]/div')
        #buttons inside the container
        buttons = buttons_container_div.find_elements(By.TAG_NAME,'button')
        if len(buttons) == 2:
            buttons[1].click()
            time.sleep(20)
            section_container = driver.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[2]/div/main/div[1]/div/div')
            driver.execute_script("arguments[0].scrollIntoView();", section_container)            #find the content just wrote by chatgpt
            bottom_div = driver.find_element(By.CSS_SELECTOR,'#__next > div.overflow-hidden.w-full.h-full.relative.flex.z-0 > div.relative.flex.h-full.max-w-full.flex-1.overflow-hidden > div > main > div.flex-1.overflow-hidden > div > div > div > div.h-32.md\:h-48.flex-shrink-0')
            # Get previous sibling of mydiv
            previous_sibling = bottom_div.find_element(By.XPATH, "preceding-sibling::*[1]")
            #Printout the latest answer from ChatGPT
            print(previous_sibling.text)
            time.sleep(10)
        elif len(buttons)==1:
            section_container = driver.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[2]/div/main/div[1]/div/div')
            driver.execute_script("arguments[0].scrollIntoView();", section_container) 
            bottom_div = driver.find_element(By.CSS_SELECTOR,'#__next > div.overflow-hidden.w-full.h-full.relative.flex.z-0 > div.relative.flex.h-full.max-w-full.flex-1.overflow-hidden > div > main > div.flex-1.overflow-hidden > div > div > div > div.h-32.md\:h-48.flex-shrink-0')
            # Get previous sibling of mydiv
            previous_sibling = bottom_div.find_element(By.XPATH, "preceding-sibling::*[1]")
            #Printout the latest answer from ChatGPT
            print(previous_sibling.text)
            time.sleep(10)

# %%
def scan_all_results(prompt):
    prompt_field =  driver.find_element(By.ID,'prompt-textarea')
    prompt_field.clear()
    #send prompt to textarea
    prompt_field.send_keys(prompt)
    #enter to write content
    enter_btn = prompt_field.find_element(By.XPATH, "following-sibling::*[1]")
    if enter_btn.is_enabled():
        driver.execute_script ("arguments[0].click();",enter_btn)
        time.sleep(50)
        #buttone where we can click to regenerate respnse or stop regenerate or continue:
        buttons_container_div =  driver.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[2]/div/main/div[2]/form/div/div[1]/div')
        #buttons inside the container
        buttons = buttons_container_div.find_elements(By.TAG_NAME,'button')
        if len(buttons) == 2:
            buttons[1].click()
            time.sleep(40)
        if len(buttons)==1:
            if buttons[0]=="Continue generating":
                buttons[0].click()
                time.sleep(40)
            else:
                time.sleep(10)

# %%
driver.execute_script("window.scrollTo(0, 2000);")

# %%
//*[@id="__next"]/div[1]/div[2]/div/main/div[2]/form/div/div[1]/div/div[2]/div

# %%
section = driver.find_element(By.XPATH, '//*[@id="__next"]/div[1]/div[2]/div/main/div[1]/div/div/div')
section.find_elements(By.CLASS_NAME,"bg-gray-50")[0].text

# %%
# Out:
# 'Tôi không thể truy cập Internet và do đó không có thông tin về nhà cái 123B đến thời điểm hiện tại (Tháng 7 năm 2023). Tôi chỉ có thể cung cấp thông tin đến thời điểm 2021.\nNếu bạn quan tâm về nhà cái 123B, bạn nên tự tìm kiếm thông tin trên trình duyệt web hoặc các nguồn tin tức uy tín để có thông tin cập nhật nhất về nhà cái này. Lưu ý luôn luôn tìm hiểu và xem xét cẩn thận trước khi tham gia vào bất kỳ hoạt động cá cược nào, đặc biệt là đối với các nhà cái hoặc dịch vụ trực tuyến.'

# %%
buttons_container_div = driver.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[2]/div/main/div[2]/form/div/div[1]/div')
button = buttons_container_div.find_elements(By.TAG_NAME,'button')

# %%
button[0].text
# Out:
# 'Continue generating'

# %%
prompt_field =  driver.find_element(By.ID,'prompt-textarea')
prompt_field.clear()
#enter to write content
enter_btn = prompt_field.find_element(By.XPATH, "following-sibling::*[1]")

# %%
enter_btn.get_attribute("class")
# Out:
# 'absolute p-1 rounded-md md:bottom-3 md:p-2 md:right-3 dark:hover:bg-gray-900 dark:disabled:hover:bg-transparent right-2 disabled:text-gray-400 enabled:bg-brand-purple text-white bottom-1.5 transition-colors disabled:opacity-40'

# %%
enter_btn.is_enabled()
# Out:
# True

# %%
buttons_container_div =  driver.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[2]/div/main/div[2]/form/div/div[1]/div')

# %%
len(buttons_container_div.find_elements(By.TAG_NAME,'button'))
# Out:
# 2

# %%
buttons_container_div.find_elements(By.TAG_NAME,'button')[1].click()

# %%
len(driver.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[2]/div/main/div[2]/form/div/div[1]/div'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[83], line 1
# ----> 1 len(driver.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[2]/div/main/div[2]/form/div/div[1]/div'))
#
# TypeError: object of type 'WebElement' has no len()

# %%
driver.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[2]/div/main/div[2]/form/div/div[1]/div')
# Out:
# <undetected_chromedriver.webelement.WebElement (session="59464b76484dfcc919d9feb99137326a", element="6B47B23C935A84E5E02144FAEC410625_element_8282")>

# %%
section_container = driver.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[2]/div/main/div[1]/div/div')

# %%
section_container.outerHTML
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[95], line 1
# ----> 1 section_container.outerHTML
#
# AttributeError: 'WebElement' object has no attribute 'outerHTML'

# %%
#This button show status of answer from ChatGPT

# %%
status_btn = driver.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[2]/div/main/div[2]/form/div/div[1]/div/button')

# %%
status_btn.text
# Out:
# 'Regenerate response'

# %%
//*[@id="__next"]/div[1]/div[2]/div/main/div[2]/form/div/div[1]/div/button
//*[@id="__next"]/div[1]/div[2]/div/main/div[2]/form/div/div[1]/div/button

# %%
###### Wait until value of status_btn = 'Regenerate response' to execute next prompt

# %%
#url = 'https://chat.openai.com/'
#driver.get(url)

# %%
#Selenium fill in username
'''email_field = driver.find_element(By.ID,'username')
email_field.send_keys(username)
time.sleep(2)'''
# Out:
# "email_field = driver.find_element(By.ID,'username')\nemail_field.send_keys(username)\ntime.sleep(2)"

# %%
#The container of status button, message field 
bottom_div = driver.find_element(By.CSS_SELECTOR,'#__next > div.overflow-hidden.w-full.h-full.relative.flex.z-0 > div.relative.flex.h-full.max-w-full.flex-1.overflow-hidden > div > main > div.flex-1.overflow-hidden > div > div > div > div.h-32.md\:h-48.flex-shrink-0')

# %%
# Get previous sibling of mydiv
previous_sibling = bottom_div.find_element(By.XPATH, "preceding-sibling::*[1]")
#Printout the latest answer from ChatGPT
print(previous_sibling.text)
# Out:
# 2 / 2
# Lợi ích của việc rút tiền từ nhà cái 123B - Trải nghiệm cá cược tiện lợi và đáng tin cậy
# Khi tham gia cá độ trực tuyến tại nhà cái 123B, một trong những điểm đáng chú ý mà người chơi luôn quan tâm đó chính là việc rút tiền từ tài khoản. Việc rút tiền 123B không chỉ đơn thuần là quy trình đơn giản mà còn mang lại nhiều lợi ích tuyệt vời cho người chơi. Dưới đây là một số lý do tại sao việc rút tiền từ nhà cái 123B đáng giá và đáng tin cậy.
# 1. Tiến trình rút tiền nhanh chóng và thuận tiện:
# ...

# %%
prompts_thể_thao_abc_gp = ['Bạn là một chuyên gia về viết nội dung cho các website cá độ, đồng thời bạn cũng am hiểu về lĩnh vực cá độ trực tuyến.Hãy viết một bài viết về nói về Giới thiệu tổng quan nhà cái 123B. Bài viết đó phải chứa từ khóa "rút tiền 123B" ít nhất một lần và nội dung bài viết phải liên quan đến thương hiệu 123B. Hãy đảm bảo rằng dung bài viết vượt quá 200 chữ',
 'Ở đoạn tiếp theo hãy viết một bài viết về nói về Giới thiệu về lợi ích của việc rút tiền từ nhà cái 123B. Bài viết đó phải chứa từ khóa "rút tiền 123B" ít nhất một lần và nội dung bài viết phải liên quan đến thương hiệu 123B. Hãy đảm bảo rằng dung bài viết vượt quá 200 chữ , nội dung ở đoạn văn này sẽ nối tiếp nội dung ở bài trước để có thể trở thành một đoạn văn hoàn chỉnh ',
 'ở đoạn này hãy viết một bài viết về nói về Các quy định về việc rút tiền 123B. Bài viết đó phải chứa từ khóa "rút tiền 123B" ít nhất một lần và nội dung bài viết phải liên quan đến thương hiệu 123B. Hãy đảm bảo rằng dung bài viết vượt quá 200 chữ, nội dung ở đoạn văn này sẽ nối tiếp nội dung ở các bài trước để có thể trở thành một đoạn văn hoàn chỉnh',
 'tiếp theo, hãy viết một bài viết về nói về Quy trình rút tiền 123B. Bài viết đó phải chứa từ khóa "rút tiền 123B" ít nhất một lần và nội dung bài viết phải liên quan đến thương hiệu 123B. Hãy đảm bảo rằng dung bài viết vượt quá 200 chữ,nội dung ở đoạn văn này sẽ nối tiếp nội dung ở các bài trước để có thể trở thành một đoạn văn hoàn chỉnh',
 'tiếp theo, viết một bài viết về nói về Ưu điểm của dịch vụ rút tiền 123B. Bài viết đó phải chứa từ khóa "rút tiền 123B" ít nhất một lần và nội dung bài viết phải liên quan đến thương hiệu 123B. Hãy đảm bảo rằng dung bài viết vượt quá 200 chữ, nội dung ở đoạn văn này sẽ nối tiếp nội dung ở các bài trước để có thể trở thành một đoạn văn hoàn chỉnh',
 'Hãy viết một bài viết về nói về Các phương thức rút tiền trên 123B. Bài viết đó phải chứa từ khóa "rút tiền 123B" ít nhất một lần và nội dung bài viết phải liên quan đến thương hiệu 123B. Hãy đảm bảo rằng dung bài viết vượt quá 200 chữ,nội dung ở đoạn văn này sẽ nối tiếp nội dung ở các bài trước để có thể trở thành một đoạn văn hoàn chỉnh',
 'Hãy viết một bài viết về nói về Các câu hỏi thường gặp về rút tiền 123B. Bài viết đó phải chứa từ khóa "rút tiền 123B" ít nhất một lần và nội dung bài viết phải liên quan đến thương hiệu 123B. Hãy đảm bảo rằng dung bài viết vượt quá 200 chữ,nội dung ở đoạn văn này sẽ nối tiếp nội dung ở các bài trước để có thể trở thành một đoạn văn hoàn chỉnh',
 'Hãy viết một bài viết về nói về Những lưu ý khi rút tiền 123B. Bài viết đó phải chứa từ khóa "rút tiền 123B" ít nhất một lần và nội dung bài viết phải liên quan đến thương hiệu 123B. Hãy đảm bảo rằng dung bài viết vượt quá 200 chữ,nội dung ở đoạn văn này sẽ nối tiếp nội dung ở các bài trước để có thể trở thành một đoạn văn hoàn chỉnh',
 'Hãy viết một bài viết về nói về Tổng kết dịch vụ rút tiền 123B. Bài viết đó phải chứa từ khóa "rút tiền 123B" ít nhất một lần và nội dung bài viết phải liên quan đến thương hiệu 123B. Hãy đảm bảo rằng dung bài viết vượt quá 200 chữ,nội dung ở đoạn văn này sẽ nối tiếp nội dung ở các bài trước để có thể trở thành một đoạn văn hoàn chỉnh']

# %%
# Out:
# Giới thiệu về xóc đĩa
#  _______________________________________________
# Luật chơi xóc đĩa 123 và các thuật ngữ thông dụng trong xóc đĩa 123B
#  _______________________________________________
# Những ưu điểm khi chơi xóc đĩa 123B
#  _______________________________________________
# Các chiến thuật chơi xóc đĩa 123B cho tỉ lệ thắng cao nhất
#  _______________________________________________
# Những chương trình khuyến mãi khi chơi xóc đĩa 123B
#  _______________________________________________
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[133], line 3
#       1 for i in range(0, len(prompts_xóc_đĩa_123B)):
#       2     print(outline_xóc_đĩa_123B[i],'\n','_______________________________________________')
# ----> 3     scan_all_results(prompts_xóc_đĩa_123B[i])
#       4     html_element = driver.find_element(By.TAG_NAME,'html')
# ...

# %%
articles = section.find_elements(By.CLASS_NAME,"bg-gray-50")
for i in articles:
    print(i.text)
# Out:
# Tôi không thể truy cập Internet và do đó không có thông tin về nhà cái 123B đến thời điểm hiện tại (Tháng 7 năm 2023). Tôi chỉ có thể cung cấp thông tin đến thời điểm 2021.
# Nếu bạn quan tâm về nhà cái 123B, bạn nên tự tìm kiếm thông tin trên trình duyệt web hoặc các nguồn tin tức uy tín để có thông tin cập nhật nhất về nhà cái này. Lưu ý luôn luôn tìm hiểu và xem xét cẩn thận trước khi tham gia vào bất kỳ hoạt động cá cược nào, đặc biệt là đối với các nhà cái hoặc dịch vụ trực tuyến.
# Tôi không thể truy cập Internet và không có thông tin cụ thể về nhà cái 789bet đến thời điểm hiện tại (Tháng 7 năm 2023). Như đã đề cập trước đó, tôi chỉ có thông tin đến tháng 9 năm 2021.
# ...

# %%
section
# Out:
# <undetected_chromedriver.webelement.WebElement (session="e7e5d5cb3208bd443e2fbc27de63b17f", element="372AC07F8DB093667C64078E993CDE92_element_1087")>

# %%
driver.quit()

# %%
from selenium.webdriver.common.keys import Keys

# %%
driver.quit()

# %%
scroll_answers()

# %%
#Selenium fill in password
password_field = driver.find_element(By.ID,'password')
password_field.send_keys(password)
time.sleep(2)

# %%
#Selenium click on login button
#ID= prompt-textarea
prompt = "Hellow world"
prompt_field = driver.find_element(By.ID,'prompt-textarea')
prompt_field.send_keys(prompt)
time.sleep(3)

# %%
#Get content of jobs page
job_url = 'https://www.linkedin.com/jobs/'
driver.get(job_url)
time.sleep(10)

# %%
#Fill in search box for job
location_input_search_field = driver.find_element(By.CLASS_NAME,'jobs-search-box__text-input')
location_input_search_field.clear()
seach_field.click()
location_input_search_field.send_keys('data analyst')

# %%
#Fill in search box for location
seach_field = driver.find_element(By.XPATH,"//input[contains(@aria-label, 'City, state, or zip code')]")
seach_field.click()
time.sleep(5)
seach_field.clear()
seach_field.send_keys('Germany')

# %%
#Submit form to get the result
seach_field.send_keys(Keys.RETURN)

# %%
#Function to smoothly scroll down the job list
def scroll_job_list():
    element = driver.find_element(By.XPATH,"/html/body/div[6]/div[3]/div[4]/div/div/main/div/section[1]/div/footer/div/div[1]")
    number = 0
    while number < 10:
        driver.execute_script("arguments[0].scrollIntoView({ behavior: 'smooth', block: 'end', inline: 'start' });",element)
        time.sleep(1)
        number +=1

# %%
#Once all jobs on list display, crappe all the  job url
def get_job_urls():
    page_source = BeautifulSoup(driver.page_source,'html.parser')
    job_ads = page_source.find_all('a',class_ = 'job-card-list__title')
    for url in job_ads:
        job_path = url.get('href')
        job_url = 'https://www.linkedin.com' + job_path
        if job_url not in job_urls:
            job_urls.append(job_url)

# %%
number_of_page = 40
job_urls = []
for page in range(1,number_of_page + 1):
    try:
        print(page)
        button = driver.find_element(By.XPATH,"//button//*[contains(., "+str(page)+")]/..")
        button.click()
        time.sleep(10)
        scroll_job_list()
        time.sleep(7)
        get_job_urls()
        print("found {} jobs after page {}".format(len(job_urls),page))
    except NoSuchElementException:
        button2 = driver.find_element(By.XPATH,"//button//*[contains(., '…')]/..")
        button2.click()
    except ElementClickInterceptedException:
        element = driver.-find_element(By.XPATH,"//button//*[contains(., "+str(page)+")]/..")
        driver.execute_script("arguments[0].click();", element)

# %%
#Save all job urls to txt file for later use
with open("file.txt", "w") as output:
    output.write(str(job_urls))
